# %% [markdown]
# ## Prepare a classification model using SVM for Salary Data:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading Training Data

# %%
salary_train=pd.read_csv("SalaryData_train.csv")

# %%
salary_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
salary_train.tail()
# Out:
#        age      workclass    education  educationno        maritalstatus  \
# 30156   27        Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40        Private      HS-grad            9   Married-civ-spouse
# 30158   58        Private      HS-grad            9              Widowed
# 30159   22        Private      HS-grad            9        Never-married
# 30160   52   Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation relationship    race      sex  capitalgain  \
# 30156        Tech-support         Wife   White   Female            0
# 30157   Machine-op-inspct      Husband   White     Male            0
# 30158        Adm-clerical    Unmarried   White   Female            0
# 30159        Adm-clerical    Own-child   White     Male            0
# 30160     Exec-managerial         Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K

# %% [markdown]
# # Reading Test Data

# %%
salary_test=pd.read_csv('SalaryData_test.csv')

# %%
salary_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
salary_test.tail()
# Out:
#        age      workclass   education  educationno        maritalstatus  \
# 15055   33        Private   Bachelors           13        Never-married
# 15056   39        Private   Bachelors           13             Divorced
# 15057   38        Private   Bachelors           13   Married-civ-spouse
# 15058   44        Private   Bachelors           13             Divorced
# 15059   35   Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#              occupation    relationship                 race      sex  \
# 15055    Prof-specialty       Own-child                White     Male
# 15056    Prof-specialty   Not-in-family                White   Female
# 15057    Prof-specialty         Husband                White     Male
# 15058      Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059   Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K

# %% [markdown]
# # Merging Train and Test Data

# %%
salary_data = salary_train.append(salary_test)

# %%
salary_data
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0            Adm-clerical   Not-in-family                White     Male
# 1         Exec-managerial         Husband                White     Male
# 2       Handlers-cleaners   Not-in-family                White     Male
# 3       Handlers-cleaners         Husband                Black     Male
# 4          Prof-specialty            Wife                Black   Female
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0             2174            0            40   United-States   <=50K
# 1                0            0            13   United-States   <=50K
# 2                0            0            40   United-States   <=50K
# 3                0            0            40   United-States   <=50K
# 4                0            0            40            Cuba   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [45221 rows x 14 columns]

# %% [markdown]
# # EDA

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45221 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45221 non-null  int64
#  1   workclass      45221 non-null  object
#  2   education      45221 non-null  object
#  3   educationno    45221 non-null  int64
#  4   maritalstatus  45221 non-null  object
#  5   occupation     45221 non-null  object
#  6   relationship   45221 non-null  object
#  7   race           45221 non-null  object
#  8   sex            45221 non-null  object
#  9   capitalgain    45221 non-null  int64
#  10  capitalloss    45221 non-null  int64
#  11  hoursperweek   45221 non-null  int64
#  12  native         45221 non-null  object
#  13  Salary         45221 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
salary_data.shape
# Out:
# (45221, 14)

# %%
salary_data.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_data.duplicated().sum()
# Out:
# 5982

# %%
salary_data[salary_data.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
# 15057   38   Private      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 326       Exec-managerial         Husband   White     Male            0
# 364          Craft-repair   Not-in-family   White     Male            0
# 518     Handlers-cleaners       Unmarried   Black   Female            0
# 525          Craft-repair       Own-child   White     Male            0
# 619       Exec-managerial         Husband   White     Male            0
# ...                   ...             ...     ...      ...          ...
# 15044        Craft-repair       Own-child   White     Male            0
# 15049   Handlers-cleaners         Husband   White     Male            0
# 15052        Craft-repair         Husband   White     Male            0
# 15053       Other-service       Own-child   White   Female            0
# 15057      Prof-specialty         Husband   White     Male            0
#
#        capitalloss  hoursperweek          native  Salary
# 326              0            40   United-States    >50K
# 364              0            50   United-States   <=50K
# 518              0            40   United-States   <=50K
# 525              0            40   United-States   <=50K
# 619              0            40   United-States    >50K
# ...            ...           ...             ...     ...
# 15044            0            40   United-States   <=50K
# 15049            0            40   United-States   <=50K
# 15052            0            40   United-States   <=50K
# 15053            0            40   United-States   <=50K
# 15057            0            50   United-States   <=50K
#
# [5982 rows x 14 columns]

# %% [markdown]
# # Discription of the Data

# %%
salary_data.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  45221.000000  45221.000000  45221.000000  45221.000000  45221.000000
# mean      38.548086     10.118463   1101.454700     88.548617     40.938038
# std       13.217981      2.552909   7506.511295    404.838249     12.007640
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %% [markdown]
# # Analyzing Unique Values for each Features

# %%
salary_data["sex"].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
salary_data["race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
salary_data["native"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#        ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#        ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#        ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#        ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#        ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#        ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#        ' Hungary'], dtype=object)

# %%
salary_data["maritalstatus"].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
salary_data["relationship"].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
salary_data["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
salary_data["education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#        ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#        ' 12th', ' 1st-4th'], dtype=object)

# %%
salary_data["occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#        ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#        ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
salary_data["Salary"].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
salary_data
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0            Adm-clerical   Not-in-family                White     Male
# 1         Exec-managerial         Husband                White     Male
# 2       Handlers-cleaners   Not-in-family                White     Male
# 3       Handlers-cleaners         Husband                Black     Male
# 4          Prof-specialty            Wife                Black   Female
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0             2174            0            40   United-States   <=50K
# 1                0            0            13   United-States   <=50K
# 2                0            0            40   United-States   <=50K
# 3                0            0            40   United-States   <=50K
# 4                0            0            40            Cuba   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [45221 rows x 14 columns]

# %% [markdown]
# # Doing Label Encoder On Target Column

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
salary_data["Salary"]=encoder.fit_transform(salary_data["Salary"])

# %%
salary_data
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0            Adm-clerical   Not-in-family                White     Male
# 1         Exec-managerial         Husband                White     Male
# 2       Handlers-cleaners   Not-in-family                White     Male
# 3       Handlers-cleaners         Husband                Black     Male
# 4          Prof-specialty            Wife                Black   Female
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0             2174            0            40   United-States       0
# 1                0            0            13   United-States       0
# 2                0            0            40   United-States       0
# 3                0            0            40   United-States       0
# 4                0            0            40            Cuba       0
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States       0
# 15056            0            0            36   United-States       0
# 15057            0            0            50   United-States       0
# 15058         5455            0            40   United-States       0
# 15059            0            0            60   United-States       1
#
# [45221 rows x 14 columns]

# %% [markdown]
# # Using Barplot To Analyze Data

# %%
sns.barplot("Salary","age",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='age'>

# %% [markdown]
# # Observation:
# In class 0 the age between 30 to 40 male and female are having equal amount of salary which is more than or equal to 50k and in class 1 the males having more than age of 40 having less salary than 50k  as compared to females

# %%
sns.barplot("Salary","workclass",hue='sex',data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='workclass'>

# %% [markdown]
# # Observation:
# In each sector of the working class Males are having more salaries than female except without pay females are having more salaries and we can see the outliers as well

# %%
sns.barplot("Salary","education",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='education'>

# %% [markdown]
# # Observation:
# In education sector also males are having more salaries than female and we can see some outliers as well

# %%
sns.barplot("Salary","educationno",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='educationno'>

# %% [markdown]
# # Observation:
# In both the classes the females are having slightly higher salaries than males

# %%
sns.barplot("Salary","maritalstatus",hue='sex',data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='maritalstatus'>

# %% [markdown]
# # Observation:
# In Married-civ-spouse and Married-AF_spouse the females are having high salaries than the males but in rest of the categories the males are having High salaries than females

# %%
sns.barplot('Salary','occupation',hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='occupation'>

# %% [markdown]
# # Observation:
# In occupation the males are having high salaries than females and also seeing some outliers

# %%
sns.barplot("Salary","relationship",hue='sex',data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='relationship'>

# %% [markdown]
# # Observation:
# In relationships the males are having more salaries than females

# %%
sns.barplot('Salary',"race",hue='sex',data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='race'>

# %% [markdown]
# # Observation:
# In race the males are having more salaries than females

# %%
sns.barplot("Salary","capitalgain",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='capitalgain'>

# %% [markdown]
# # Observation:
# In capitalgain the males are less capital gain than Females

# %%
sns.barplot('Salary',"capitalloss",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='capitalloss'>

# %% [markdown]
# # Observation:
# The males are having more capiral loss than females

# %%
sns.barplot("Salary","hoursperweek",hue='sex',data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='hoursperweek'>

# %% [markdown]
# # Observation:
# In hours per week the males are having more salaries than females

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.barplot('Salary',"native",hue="sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='native'>

# %% [markdown]
# # Observation:
# As we can see that most of the native regions are showing that the males are having more salaries than females

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot("age",data=salary_data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot('workclass',data=salary_data)
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=(20,10),dpi=250)
sns.countplot("education",data=salary_data)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot('educationno',data=salary_data)
# Out:
# <AxesSubplot:xlabel='educationno', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot("maritalstatus",data=salary_data)
# Out:
# <AxesSubplot:xlabel='maritalstatus', ylabel='count'>

# %%
plt.figure(figsize=(24,10),dpi=250)
sns.countplot("occupation",data=salary_data)
# Out:
# <AxesSubplot:xlabel='occupation', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot('relationship',data=salary_data)
# Out:
# <AxesSubplot:xlabel='relationship', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot("race",data=salary_data)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
plt.figure(figsize=(15,10),dpi=250)
sns.countplot("sex",data=salary_data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(20,10),dpi=250)
sns.countplot("hoursperweek",data=salary_data)
# Out:
# <AxesSubplot:xlabel='hoursperweek', ylabel='count'>

# %%
salary_data["native"].value_counts()
# Out:
#  United-States                 41292
#  Mexico                          903
#  Philippines                     283
#  Germany                         193
#  Puerto-Rico                     175
#  Canada                          163
#  India                           147
#  El-Salvador                     147
#  Cuba                            133
#  England                         119
#  China                           113
#  Jamaica                         103
#  South                           101
#  Italy                           100
#  Dominican-Republic               97
#  Japan                            89
#  Guatemala                        86
#  Vietnam                          83
#  Columbia                         82
#  Poland                           81
#  Haiti                            69
#  Portugal                         62
#  Iran                             56
#  Taiwan                           55
#  Greece                           49
#  Nicaragua                        48
#  Peru                             45
#  Ecuador                          43
#  France                           36
#  Ireland                          36
#  Thailand                         29
#  Hong                             28
#  Trinadad&Tobago                  26
#  Cambodia                         26
#  Yugoslavia                       23
#  Outlying-US(Guam-USVI-etc)       22
#  Laos                             21
#  Scotland                         20
#  Honduras                         19
#  Hungary                          18
# Name: native, dtype: int64

# %% [markdown]
# # Piechart

# %%
plt.figure(figsize = (12,8))
plt.pie(salary_data['Salary'].value_counts(),
       labels=salary_data.Salary.unique(),
       autopct= '%.2f%%',
       shadow= True,
       startangle= 181,
       textprops = {'size':'large',
                   'fontweight':'bold',
                    'rotation':'0',
                   'color':'black'})
plt.legend(loc= 'upper right')
plt.title("Class Type Distribution Pie Chart", fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# # Observation:
# As we can see that the majority of tha salaries are more than 50k

# %% [markdown]
# # Coverting Categorical data into Numeric Data

# %%
salary_data
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0            Adm-clerical   Not-in-family                White     Male
# 1         Exec-managerial         Husband                White     Male
# 2       Handlers-cleaners   Not-in-family                White     Male
# 3       Handlers-cleaners         Husband                Black     Male
# 4          Prof-specialty            Wife                Black   Female
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0             2174            0            40   United-States       0
# 1                0            0            13   United-States       0
# 2                0            0            40   United-States       0
# 3                0            0            40   United-States       0
# 4                0            0            40            Cuba       0
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States       0
# 15056            0            0            36   United-States       0
# 15057            0            0            50   United-States       0
# 15058         5455            0            40   United-States       0
# 15059            0            0            60   United-States       1
#
# [45221 rows x 14 columns]

# %%
salary_data["education"]=encoder.fit_transform(salary_data["education"])
salary_data["workclass"]=encoder.fit_transform(salary_data["workclass"])
salary_data["maritalstatus"]=encoder.fit_transform(salary_data["maritalstatus"])
salary_data["sex"]=encoder.fit_transform(salary_data["sex"])
salary_data["race"]=encoder.fit_transform(salary_data["race"])
salary_data["occupation"]=encoder.fit_transform(salary_data["occupation"])
salary_data["relationship"]=encoder.fit_transform(salary_data["relationship"])
salary_data["native"]=encoder.fit_transform(salary_data["native"])

# %%
salary_data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0                 1     4    1         2174            0            40
# 1                 0     4    1            0            0            13
# 2                 1     4    1            0            0            40
# 3                 0     2    1            0            0            40
# 4                 5     2    0            0            0            40
# ...             ...   ...  ...          ...          ...           ...
# 15055             3     4    1            0            0            40
# 15056             1     4    0            0            0            36
# 15057             0     4    1            0            0            50
# 15058             3     1    1         5455            0            40
# 15059             0     4    1            0            0            60
#
#        native  Salary
# 0          37       0
# 1          37       0
# 2          37       0
# 3          37       0
# 4           4       0
# ...       ...     ...
# 15055      37       0
# 15056      37       0
# 15057      37       0
# 15058      37       0
# 15059      37       1
#
# [45221 rows x 14 columns]

# %% [markdown]
# # Standardizing the data for less processing time

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
salary_data_std = sc.fit_transform(salary_data.iloc[:,0:12])

# %%
salary_data_std
# Out:
# array([[ 0.03418971,  2.91768179, -0.34404887, ...,  0.14288357,
#         -0.21872833, -0.07812093],
#        [ 0.86639866,  1.87397267, -0.34404887, ..., -0.14673486,
#         -0.21872833, -2.32671417],
#        [-0.04146565, -0.21344557,  0.17992971, ..., -0.14673486,
#         -0.21872833, -0.07812093],
#        ...,
#        [-0.04146565, -0.21344557, -0.34404887, ..., -0.14673486,
#         -0.21872833,  0.75469138],
#        [ 0.4124665 , -0.21344557, -0.34404887, ...,  0.57997561,
#         -0.21872833, -0.07812093],
#        [-0.26843172,  0.83026355, -0.34404887, ..., -0.14673486,
#         -0.21872833,  1.58750369]])

# %%
salary_data_std1 = pd.DataFrame(data=salary_data_std,columns=["age","workclass","education","educationno","maritalstatus","occupation","relationship","sex","capitalgain","capitalloss","hoursperweek","native"])

# %%
salary_data_std1
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 0      0.034190   2.917682  -0.344049     1.128739       0.942956   -1.482608
# 1      0.866399   1.873973  -0.344049     1.128739      -0.389984   -0.737525
# 2     -0.041466  -0.213446   0.179930    -0.438118      -1.722923   -0.240804
# 3      1.093365  -0.213446  -2.439963    -1.221546      -0.389984   -0.240804
# 4     -0.798019  -0.213446  -0.344049     1.128739      -0.389984    0.752640
# ...         ...        ...        ...          ...            ...         ...
# 45216 -0.419742  -0.213446  -0.344049     1.128739       0.942956    0.752640
# 45217  0.034190  -0.213446  -0.344049     1.128739      -1.722923    0.752640
# 45218 -0.041466  -0.213446  -0.344049     1.128739      -0.389984    0.752640
# 45219  0.412467  -0.213446  -0.344049     1.128739      -1.722923   -1.482608
# 45220 -0.268432   0.830264  -0.344049     1.128739      -0.389984   -0.737525
#
#        relationship       sex  capitalgain  capitalloss  hoursperweek  \
# 0         -0.258376  0.384115     0.693790     0.142884     -0.218728
# 1         -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 2         -0.258376  0.384115     0.693790    -0.146735     -0.218728
# 3         -0.884462 -2.018716     0.693790    -0.146735     -0.218728
# 4          2.245968 -2.018716    -1.441359    -0.146735     -0.218728
# ...             ...       ...          ...          ...           ...
# 45216      0.993796  0.384115     0.693790    -0.146735     -0.218728
# 45217     -0.258376  0.384115    -1.441359    -0.146735     -0.218728
# 45218     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 45219      0.993796 -3.220132     0.693790     0.579976     -0.218728
# 45220     -0.884462  0.384115     0.693790    -0.146735     -0.218728
#
#          native
# 0     -0.078121
# 1     -2.326714
# 2     -0.078121
# 3     -0.078121
# 4     -0.078121
# ...         ...
# 45216 -0.078121
# 45217 -0.411246
# 45218  0.754691
# 45219 -0.078121
# 45220  1.587504
#
# [45221 rows x 12 columns]

# %% [markdown]
# # Splting into Train and Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
X=salary_data_std1.iloc[:,0:12]
Y=salary_data[["Salary"]]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=45)

# %%
X_train
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 26177  0.639433   1.873973   1.227887    -0.046404      -0.389984    1.497722
# 14229  0.715088  -0.213446   0.179930    -0.438118      -0.389984    1.746083
# 9156   0.412467  -0.213446  -0.344049     1.128739      -0.389984   -0.737525
# 13466  2.001229  -0.213446   0.179930    -0.438118       2.275895    0.255918
# 4245  -0.798019  -0.213446  -0.868027     0.737025       0.942956    0.752640
# ...         ...        ...        ...          ...            ...         ...
# 32469 -0.722364  -0.213446   0.441919     1.520454       0.942956    0.752640
# 16317 -0.117121   1.873973   0.179930    -0.438118      -0.389984   -0.489164
# 12895  3.211715   1.873973  -0.344049     1.128739       2.275895    0.752640
# 6012   0.109845  -0.213446   0.179930    -0.438118      -0.389984    1.249361
# 6558  -1.478917  -0.213446   0.179930    -0.438118       0.942956   -0.489164
#
#        relationship       sex  capitalgain  capitalloss  hoursperweek  \
# 26177     -0.884462 -2.018716     0.693790    -0.146735     -0.218728
# 14229     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 9156      -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 13466     -0.258376  0.384115    -1.441359    -0.146735     -0.218728
# 4245       0.993796  0.384115     0.693790    -0.146735     -0.218728
# ...             ...       ...          ...          ...           ...
# 32469     -0.258376  0.384115    -1.441359    -0.146735     -0.218728
# 16317     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 12895     -0.258376  0.384115    -1.441359    -0.146735      3.901481
# 6012      -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 6558       0.993796  0.384115     0.693790    -0.146735     -0.218728
#
#          native
# 26177 -0.078121
# 14229  0.255004
# 9156  -0.078121
# 13466 -2.160152
# 4245  -0.078121
# ...         ...
# 32469 -0.078121
# 16317  2.586878
# 12895 -3.159526
# 6012  -0.078121
# 6558  -1.743746
#
# [36176 rows x 12 columns]

# %%
X_test
# Out:
#             age  workclass  education  educationno  maritalstatus  occupation  \
# 3125   0.185500  -0.213446  -1.653995    -2.788403      -0.389984   -1.482608
# 4589   2.833438  -0.213446  -1.130017    -2.004975      -0.389984    1.001001
# 28875  1.017709  -0.213446  -0.344049     1.128739      -0.389984   -0.737525
# 13296  1.169020  -0.213446   0.179930    -0.438118      -0.389984    0.007557
# 13076  0.109845  -0.213446   0.965898     1.912168       0.942956    0.752640
# ...         ...        ...        ...          ...            ...         ...
# 3628  -0.646709  -0.213446   0.179930    -0.438118       0.942956    0.007557
# 7307  -0.722364  -0.213446   0.179930    -0.438118      -0.389984   -0.737525
# 6011  -1.251951  -0.213446   0.179930    -0.438118       0.942956   -1.482608
# 25704 -0.344087  -0.213446   0.179930    -0.438118      -0.389984   -0.985886
# 14879  1.244675  -1.257155  -0.344049     1.128739       2.275895    0.752640
#
#        relationship       sex  capitalgain  capitalloss  hoursperweek  \
# 3125      -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 4589      -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 28875     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 13296     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 13076     -0.258376  0.384115    -1.441359     1.729524     -0.218728
# ...             ...       ...          ...          ...           ...
# 3628       0.367710  0.384115    -1.441359    -0.146735     -0.218728
# 7307      -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 6011      -0.258376  0.384115    -1.441359    -0.146735     -0.218728
# 25704     -0.884462  0.384115     0.693790    -0.146735     -0.218728
# 14879     -0.258376  0.384115    -1.441359    -0.146735     -0.218728
#
#          native
# 3125  -0.078121
# 4589  -2.326714
# 28875  0.338285
# 13296 -0.078121
# 13076  0.754691
# ...         ...
# 3628  -0.494527
# 7307  -0.078121
# 6011  -2.576558
# 25704  0.754691
# 14879  0.588129
#
# [9045 rows x 12 columns]

# %%
Y_train
# Out:
#        Salary
# 26177       1
# 14229       0
# 9156        1
# 13466       0
# 4245        0
# ...       ...
# 2308        0
# 16317       0
# 12895       0
# 6012        1
# 6558        0
#
# [36176 rows x 1 columns]

# %%
Y_test
# Out:
#        Salary
# 3125        0
# 4589        0
# 28875       1
# 13296       1
# 13076       1
# ...       ...
# 3628        0
# 7307        0
# 6011        0
# 25704       0
# 14879       0
#
# [9045 rows x 1 columns]

# %% [markdown]
# # Balancing the Imbalance data using oversampling Technique

# %%
from imblearn.over_sampling import SMOTE,ADASYN
from imblearn.combine import SMOTETomek,SMOTEENN
oversample = SMOTE()
oversample2 = ADASYN()
oversample3 = SMOTETomek()
oversample4 = SMOTEENN()

# %%
X_res,Y_res = oversample4.fit_resample(X_train,Y_train)

# %%
X_res_test,Y_res_test = oversample4.fit_resample(X_test,Y_test)

# %% [markdown]
# # Creating Model For SVM

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # SVM using Linear Kernel

# %%
clf = SVC(kernel="linear")

# %%
clf.fit(X_res,Y_res)
# Out:
# SVC(kernel='linear')

# %%
predict = clf.predict(X_res_test)
pd.Series(predict).value_counts()
# Out:
# 0    5003
# 1    4907
# dtype: int64

# %% [markdown]
# # Checking accuracy_score,Confusion_matrix and Classification_report for SVM using Linear Kernel

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(Y_res_test,predict)
# Out:
# 0.858627648839556

# %%
cm = confusion_matrix(Y_res_test,predict)
cm
# Out:
# array([[4172,  570],
#        [ 831, 4337]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(33.0, 0.5, 'Truth')

# %%
print(classification_report(Y_res_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      4742
#            1       0.88      0.84      0.86      5168
#
#     accuracy                           0.86      9910
#    macro avg       0.86      0.86      0.86      9910
# weighted avg       0.86      0.86      0.86      9910

# %% [markdown]
# # Creating ROC Curve

# %% [markdown]
# # Checkiing ROC-AUC Scores for SVM using Linear Kernel

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(Y_res_test, predict)

plt.figure(figsize=(6,4))

plt.plot(fpr, tpr, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 12

plt.title('ROC curve for SVM Classifier using Linear Kernel for Predicting Salaries')

plt.xlabel('False Positive Rate (1 - Specificity)')

plt.ylabel('True Positive Rate (Sensitivity)')

plt.show()

# %%
from sklearn.metrics import roc_auc_score

ROC_AUC = roc_auc_score(Y_res_test, predict)

print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.8595

# %% [markdown]
# # SVM using Polynomial Kernel

# %%
clf2 = SVC(kernel="poly")

# %%
clf2.fit(X_res,Y_res)
# Out:
# SVC(kernel='poly')

# %%
predict2 = clf2.predict(X_res_test)
pd.Series(predict2).value_counts()
# Out:
# 0    5008
# 1    4902
# dtype: int64

# %% [markdown]
# # Accuracy-score,Confusion-Matrix and Classification-report for SVM using Polynomial

# %%
accuracy_score(Y_res_test,predict2)
# Out:
# 0.9057517658930373

# %%
cm2 = confusion_matrix(Y_res_test,predict2)
cm2
# Out:
# array([[4408,  334],
#        [ 600, 4568]], dtype=int64)

# %%
sns.heatmap(cm2,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(30.0, 0.5, 'Truth')

# %%
print(classification_report(Y_res_test,predict2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      4742
#            1       0.93      0.88      0.91      5168
#
#     accuracy                           0.91      9910
#    macro avg       0.91      0.91      0.91      9910
# weighted avg       0.91      0.91      0.91      9910

# %% [markdown]
# # ROC and AUC-Score for SVM using Polynomial Kernels

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(Y_res_test, predict2)

plt.figure(figsize=(6,4))

plt.plot(fpr, tpr, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 12

plt.title('ROC curve for SVM Classifier usning Polynomial kernel for Predicting Salaries')

plt.xlabel('False Positive Rate (1 - Specificity)')

plt.ylabel('True Positive Rate (Sensitivity)')

plt.show()

# %%
from sklearn.metrics import roc_auc_score

ROC_AUC = roc_auc_score(Y_res_test, predict2)

print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.9067

# %% [markdown]
# # SVM using RBF kernel

# %%
clf3 = SVC(kernel="rbf")

# %%
clf3.fit(X_res,Y_res)
# Out:
# SVC()

# %%
predict3 = clf3.predict(X_res_test)
pd.Series(predict3).value_counts()
# Out:
# 1    5132
# 0    4778
# dtype: int64

# %% [markdown]
# # Accuracy-Score,Confusion-Matrix and Classic=fication-Report for SVM using RBF Kernel

# %%
accuracy_score(Y_res_test,predict3)
# Out:
# 0.9374369323915237

# %%
cm3 = confusion_matrix(Y_res_test,predict3)
cm3
# Out:
# array([[4450,  292],
#        [ 328, 4840]], dtype=int64)

# %%
sns.heatmap(cm3,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(30.0, 0.5, 'Truth')

# %%
print(classification_report(Y_res_test,predict3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      4742
#            1       0.94      0.94      0.94      5168
#
#     accuracy                           0.94      9910
#    macro avg       0.94      0.94      0.94      9910
# weighted avg       0.94      0.94      0.94      9910

# %% [markdown]
# # ROC and AUC-Score for SVM using RBF Kernel

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(Y_res_test, predict3)

plt.figure(figsize=(6,4))

plt.plot(fpr, tpr, linewidth=2)

plt.plot([0,1], [0,1], 'k--' )

plt.rcParams['font.size'] = 12

plt.title('ROC curve for SVM Classifier usning RBF kernel for Predicting Salaries')

plt.xlabel('False Positive Rate (1 - Specificity)')

plt.ylabel('True Positive Rate (Sensitivity)')

plt.show()

# %%
from sklearn.metrics import roc_auc_score

ROC_AUC = roc_auc_score(Y_res_test, predict3)

print('ROC AUC : {:.4f}'.format(ROC_AUC))
# Out:
# ROC AUC : 0.9375

# %% [markdown]
# # Observation:
# After applying several oversampling technique we found the best results on SMOTEENN we have better accuracy in this technique as compared to other oversampling technique
